# %%
import json
import pandas as pd
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()

# %%
table_name = 'FINAL_DATA'
sf_df = my_session.sql("select * from {}".format(table_name))
df = sf_df.to_pandas()

# %%
df
# Out:
#        MEMBER_ID      MEMBER_NAME  MEMBER_DOB  \
# 0      MID000001   Vallie Bachman  1980-01-08
# 1      MID000002   Jade Strassner  1986-11-19
# 2      MID000003    Mari Candlish  1989-01-27
# 3      MID000004      Serina Leto  1984-03-08
# 4      MID000005     Brett Butzen  1970-01-23
# ...          ...              ...         ...
# 99995  MID241996         Nu Ragel  1967-01-24
# 99996  MID241997         Lucy Hoa  1973-04-30
# 99997  MID241998    Lucina Klimek  1991-07-03
# 99998  MID241999   Maurine Dopico  1976-05-17
# 99999  MID242000  Cathrine Cousey  1987-06-09
#
#                          MEMBER_EMPLOYMENT MEMBER_GENDER MEMBER_CITY_TOWN  \
# 0                 The University of Sydney        Female           Hobart
# 1                        Curtin University        Female        Gladstone
# 2                University of New England        Female          Walgett
# 3                      Griffith University        Female      Paynesville
# 4                      La Trobe University          Male       Palmerston
# ...                                    ...           ...              ...
# 99995                  La Trobe University          Male         Urraween
# 99996            University of New England          Male           Wilton
# 99997  Queensland University of Technology          Male        Vincentia
# 99998                      RMIT University          Male             Eden
# 99999          The University of Newcastle          Male        Moss Vale
#
#              MEMBER_STATE  MEMBER_CONTACT_VERIFIED  \
# 0                Tasmania                    False
# 1              Queensland                    False
# 2         New South Wales                     True
# 3                Victoria                     True
# 4      Northern Territory                     True
# ...                   ...                      ...
# 99995          Queensland                    False
# 99996     New South Wales                     True
# 99997     New South Wales                    False
# 99998     New South Wales                    False
# 99999     New South Wales                     True
#
#                                                PORTFOLIO  \
# 0                           ['CCSO', 'MPJ', 'ABC', 'EG']
# 1      ['EG', 'ABC', 'ONH', 'MZNA', 'FWC', 'GMNA', 'T...
# 2             ['MMM', 'PG', 'NTIC', 'EPF', 'SM', 'ALPA']
# 3            ['JJN', 'PG', 'AB', 'OOGGL', 'NTIC', 'MMM']
# 4      ['SM', 'JJN', 'ALPA', 'NTIC', 'HD', 'AB', 'MZNA']
# ...                                                  ...
# 99995  ['MTFS', 'MPJ', 'SM', 'OCST', 'NTIC', 'CCSO', ...
# 99996                                ['GS', 'JJN', 'HD']
# 99997                                ['ONH', 'AB', 'GS']
# 99998      ['MPJ', 'MZNA', 'FWC', 'HD', 'ALPA', 'OOGGL']
# 99999   ['MMM', 'PG', 'MZNA', 'EPF', 'HD', 'JJN', 'ABC']
#
#        INTITIAL_INVVESTMENT  \
# 0                      5000
# 1                     69000
# 2                     49000
# 3                      1000
# 4                      5000
# ...                     ...
# 99995                 90000
# 99996                  5000
# 99997                  1000
# 99998                  5000
# 99999                 80000
#
#                                                ORG_INVST  \
# 0      {'Initial Investment': '$5,000.00', 'Expected ...
# 1      {'Initial Investment': '$69,000.00', 'Expected...
# 2      {'Initial Investment': '$49,000.00', 'Expected...
# 3      {'Initial Investment': '$1,000.00', 'Expected ...
# 4      {'Initial Investment': '$5,000.00', 'Expected ...
# ...                                                  ...
# 99995  {'Initial Investment': '$90,000.00', 'Expected...
# 99996  {'Initial Investment': '$5,000.00', 'Expected ...
# 99997  {'Initial Investment': '$1,000.00', 'Expected ...
# 99998  {'Initial Investment': '$5,000.00', 'Expected ...
# 99999  {'Initial Investment': '$80,000.00', 'Expected...
#
#                                           TEMP_OPTIMIZED  \
# 0      [{'Initial Investment': '$5,000.00', 'Expected...
# 1      [{'Initial Investment': '$69,000.00', 'Expecte...
# 2      [{'Initial Investment': '$49,000.00', 'Expecte...
# 3      [{'Initial Investment': '$1,000.00', 'Expected...
# 4      [{'Initial Investment': '$5,000.00', 'Expected...
# ...                                                  ...
# 99995  [{'Initial Investment': '$90,000.00', 'Expecte...
# 99996  [{'Initial Investment': '$5,000.00', 'Expected...
# 99997  [{'Initial Investment': '$1,000.00', 'Expected...
# 99998  [{'Initial Investment': '$5,000.00', 'Expected...
# 99999  [{'Initial Investment': '$80,000.00', 'Expecte...
#
#                                       EXPECTED_PORTFOLIO  \
# 0      [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 1      [263583247.83, 1586958889.8, 183033297.12, 9.1...
# 2      [132926565.44999999, 800312599.8000001, 923047...
# 3      [55363.001, 333324.69800000003, 38444.2969, 1....
# 4      [1384075.025, 8333117.45, 961107.42, 4.7874302...
# ...                                                  ...
# 99995  [448440308.09999996, 2699930052.0, 311398804.8...
# 99996  [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 99997  [55363.001, 333324.69800000003, 38444.2969, 1....
# 99998  [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 99999  [354323206.4, 2133278064.0, 246043500.0, 1.225...
#
#                                INITIAL_INVESTMENT_STOCKS
# 0                       [1250.0, 1250.0, 1250.0, 1250.0]
# 1      [7666.666666666667, 7666.666666666667, 7666.66...
# 2      [8166.666666666667, 8166.666666666667, 8166.66...
# 3      [166.66666666666666, 166.66666666666666, 166.6...
# 4      [714.2857142857143, 714.2857142857143, 714.285...
# ...                                                  ...
# 99995  [11250.0, 11250.0, 11250.0, 11250.0, 11250.0, ...
# 99996  [1666.6666666666667, 1666.6666666666667, 1666....
# 99997  [333.3333333333333, 333.3333333333333, 333.333...
# 99998  [833.3333333333334, 833.3333333333334, 833.333...
# 99999  [11428.57142857143, 11428.57142857143, 11428.5...
#
# [100000 rows x 14 columns]

# %%
import ast
# Function to explode the 'PORTFOLIO' and 'INITIAL_INVESTMENT_STOCKS' columns
def explode_columns(df, portfolio_col, investment_col):
    df[portfolio_col] = df[portfolio_col].apply(eval)  # Convert string representation of list to actual list
    df[investment_col] = df[investment_col].apply(eval)  # Convert string representation of list to actual list
    df = df.explode([portfolio_col, investment_col])
    return df

# Columns to be exploded
portfolio_col = 'PORTFOLIO'
investment_col = 'INITIAL_INVESTMENT_STOCKS'

# Explode the specified columns
df_exploded = explode_columns(df, portfolio_col, investment_col)

# %%
df_exploded
# Out:
#        MEMBER_ID      MEMBER_NAME  MEMBER_DOB            MEMBER_EMPLOYMENT  \
# 0      MID000001   Vallie Bachman  1980-01-08     The University of Sydney
# 0      MID000001   Vallie Bachman  1980-01-08     The University of Sydney
# 0      MID000001   Vallie Bachman  1980-01-08     The University of Sydney
# 0      MID000001   Vallie Bachman  1980-01-08     The University of Sydney
# 1      MID000002   Jade Strassner  1986-11-19            Curtin University
# ...          ...              ...         ...                          ...
# 99999  MID242000  Cathrine Cousey  1987-06-09  The University of Newcastle
# 99999  MID242000  Cathrine Cousey  1987-06-09  The University of Newcastle
# 99999  MID242000  Cathrine Cousey  1987-06-09  The University of Newcastle
# 99999  MID242000  Cathrine Cousey  1987-06-09  The University of Newcastle
# 99999  MID242000  Cathrine Cousey  1987-06-09  The University of Newcastle
#
#       MEMBER_GENDER MEMBER_CITY_TOWN     MEMBER_STATE  \
# 0            Female           Hobart         Tasmania
# 0            Female           Hobart         Tasmania
# 0            Female           Hobart         Tasmania
# 0            Female           Hobart         Tasmania
# 1            Female        Gladstone       Queensland
# ...             ...              ...              ...
# 99999          Male        Moss Vale  New South Wales
# 99999          Male        Moss Vale  New South Wales
# 99999          Male        Moss Vale  New South Wales
# 99999          Male        Moss Vale  New South Wales
# 99999          Male        Moss Vale  New South Wales
#
#        MEMBER_CONTACT_VERIFIED PORTFOLIO  INTITIAL_INVVESTMENT  \
# 0                        False      CCSO                  5000
# 0                        False       MPJ                  5000
# 0                        False       ABC                  5000
# 0                        False        EG                  5000
# 1                        False        EG                 69000
# ...                        ...       ...                   ...
# 99999                     True      MZNA                 80000
# 99999                     True       EPF                 80000
# 99999                     True        HD                 80000
# 99999                     True       JJN                 80000
# 99999                     True       ABC                 80000
#
#                                                ORG_INVST  \
# 0      {'Initial Investment': '$5,000.00', 'Expected ...
# 0      {'Initial Investment': '$5,000.00', 'Expected ...
# 0      {'Initial Investment': '$5,000.00', 'Expected ...
# 0      {'Initial Investment': '$5,000.00', 'Expected ...
# 1      {'Initial Investment': '$69,000.00', 'Expected...
# ...                                                  ...
# 99999  {'Initial Investment': '$80,000.00', 'Expected...
# 99999  {'Initial Investment': '$80,000.00', 'Expected...
# 99999  {'Initial Investment': '$80,000.00', 'Expected...
# 99999  {'Initial Investment': '$80,000.00', 'Expected...
# 99999  {'Initial Investment': '$80,000.00', 'Expected...
#
#                                           TEMP_OPTIMIZED  \
# 0      [{'Initial Investment': '$5,000.00', 'Expected...
# 0      [{'Initial Investment': '$5,000.00', 'Expected...
# 0      [{'Initial Investment': '$5,000.00', 'Expected...
# 0      [{'Initial Investment': '$5,000.00', 'Expected...
# 1      [{'Initial Investment': '$69,000.00', 'Expecte...
# ...                                                  ...
# 99999  [{'Initial Investment': '$80,000.00', 'Expecte...
# 99999  [{'Initial Investment': '$80,000.00', 'Expecte...
# 99999  [{'Initial Investment': '$80,000.00', 'Expecte...
# 99999  [{'Initial Investment': '$80,000.00', 'Expecte...
# 99999  [{'Initial Investment': '$80,000.00', 'Expecte...
#
#                                       EXPECTED_PORTFOLIO  \
# 0      [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 0      [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 0      [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 0      [1384075.025, 8333117.45, 961107.42, 4.7874302...
# 1      [263583247.83, 1586958889.8, 183033297.12, 9.1...
# ...                                                  ...
# 99999  [354323206.4, 2133278064.0, 246043500.0, 1.225...
# 99999  [354323206.4, 2133278064.0, 246043500.0, 1.225...
# 99999  [354323206.4, 2133278064.0, 246043500.0, 1.225...
# 99999  [354323206.4, 2133278064.0, 246043500.0, 1.225...
# 99999  [354323206.4, 2133278064.0, 246043500.0, 1.225...
#
#       INITIAL_INVESTMENT_STOCKS
# 0                        1250.0
# 0                        1250.0
# 0                        1250.0
# 0                        1250.0
# 1                   7666.666667
# ...                         ...
# 99999              11428.571429
# 99999              11428.571429
# 99999              11428.571429
# 99999              11428.571429
# 99999              11428.571429
#
# [516866 rows x 14 columns]

# %%
# Save only the 'PORTFOLIO' and 'INITIAL_INVESTMENT_STOCKS' columns to a new CSV file
df_exploded[['PORTFOLIO', 'INITIAL_INVESTMENT_STOCKS', 'MEMBER_ID']].to_csv('PROTFOLIO.csv', index=False)

# %%
# Function to extract specific fields from ORG_INVST column
def extract_org_invst_details(org_invst_str):
    org_invst_dict = ast.literal_eval(org_invst_str)
    return pd.Series({
        'Expected_Final_Portfolio_Value': org_invst_dict.get('Expected Final Portfolio Value'),
        'Median_Final_Portfolio_Value': org_invst_dict.get('Median Final Portfolio Value'),
        'Standard_Deviation_of_Final_Portfolio_Value': org_invst_dict.get('Standard Deviation of Final Portfolio Value'),
        'Value_at_Risk': org_invst_dict.get('Value at Risk (VaR 95%)'),
        'Conditional_Value_at_Risk': org_invst_dict.get('Conditional Value at Risk (CVaR 95%)'),
        'Probability_of_Loss': org_invst_dict.get('Probability of Loss'),
        'Sharpe_Ratio': org_invst_dict.get('Sharpe Ratio')
    })

# Apply the function to the ORG_INVST column and join with the exploded DataFrame
org_invst_details = df['ORG_INVST'].apply(extract_org_invst_details)
df_final = df_exploded.join(org_invst_details)

# Select only the required columns
df_selected = df_final[['MEMBER_ID' as 'Member_ID, 'PORTFOLIO' as 'Portfolio', 'INITIAL_INVESTMENT_STOCKS' as 'Initial_Investment_Stocks', 'Expected_Final_Portfolio_Value', 'Standard_Deviation_of_Final_Portfolio_Value', 'Value_at_Risk', 'Probability_of_Loss', 'Sharpe_Ratio']]
# Out:
#   Cell In[36], line 19
#     df_selected = df_final[['MEMBER_ID' as 'Member_ID, 'PORTFOLIO' as 'Portfolio', 'INITIAL_INVESTMENT_STOCKS' as 'Initial_Investment_Stocks', 'Expected_Final_Portfolio_Value', 'Standard_Deviation_of_Final_Portfolio_Value', 'Value_at_Risk', 'Probability_of_Loss', 'Sharpe_Ratio']]
#                                         ^
# SyntaxError: invalid syntax

# %%
# Write the DataFrame to a CSV file with column names
df_selected.to_csv('original_investment_details.csv', index=False, header=True)
