# %%
import json
import pandas as pd
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()

# %%
table_name = 'FINAL_DATASET'
sf_df = my_session.sql("select * from {}".format(table_name))
df = sf_df.to_pandas()

# %%
df
# Out:
#        MEMBER_ID      MEMBER_NAME  MEMBER_DOB  \
# 0      MID000001   Vallie Bachman  1980-01-08
# 1      MID000002   Jade Strassner  1986-11-19
# 2      MID000003    Mari Candlish  1989-01-27
# 3      MID000004      Serina Leto  1984-03-08
# 4      MID000005     Brett Butzen  1970-01-23
# ...          ...              ...         ...
# 99995  MID241996         Nu Ragel  1967-01-24
# 99996  MID241997         Lucy Hoa  1973-04-30
# 99997  MID241998    Lucina Klimek  1991-07-03
# 99998  MID241999   Maurine Dopico  1976-05-17
# 99999  MID242000  Cathrine Cousey  1987-06-09
#
#                          MEMBER_EMPLOYMENT MEMBER_GENDER MEMBER_CITY_TOWN  \
# 0                 The University of Sydney        Female           Hobart
# 1                        Curtin University        Female        Gladstone
# 2                University of New England        Female          Walgett
# 3                      Griffith University        Female      Paynesville
# ...

# %%
import ast
# Function to convert string representation of list to actual list
def convert_to_list(portfolio_str):
    return ast.literal_eval(portfolio_str)

# Apply the function to the PORTFOLIO column
df['PORTFOLIO'] = df['PORTFOLIO'].apply(convert_to_list)

# Explode the PORTFOLIO column to create a row for each investment
df_exploded = df.explode('PORTFOLIO')

# Display the updated DataFrame
print(df_exploded.head())
# Out:
#    MEMBER_ID     MEMBER_NAME  MEMBER_DOB         MEMBER_EMPLOYMENT  \
# 0  MID000001  Vallie Bachman  1980-01-08  The University of Sydney
# 0  MID000001  Vallie Bachman  1980-01-08  The University of Sydney
# 0  MID000001  Vallie Bachman  1980-01-08  The University of Sydney
# 0  MID000001  Vallie Bachman  1980-01-08  The University of Sydney
# 1  MID000002  Jade Strassner  1986-11-19         Curtin University
#
#   MEMBER_GENDER MEMBER_CITY_TOWN MEMBER_STATE  MEMBER_CONTACT_VERIFIED  \
# 0        Female           Hobart     Tasmania                    False
# 0        Female           Hobart     Tasmania                    False
# 0        Female           Hobart     Tasmania                    False
# 0        Female           Hobart     Tasmania                    False
# 1        Female        Gladstone   Queensland                    False
#
#   PORTFOLIO  INTITIAL_INVVESTMENT  \
# 0      CCSO                  5000
# 0       MPJ                  5000
# ...

# %%
# Save the transformed DataFrame to a new CSV file
df_exploded.to_csv('PORTFOLIO.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:270, in CSVFormatter.save(self)
#     260 self.writer = csvlib.writer(
#     261     handles.handle,
#     262     lineterminator=self.lineterminator,
#    (...)
#     267     quotechar=self.quotechar,
#     268 )
# --> 270 self._save()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:275, in CSVFormatter._save(self)
#     274     self._save_header()
# --> 275 self._save_body()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_body(self)
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
# ...

# %%
# Or save the file as a compressed CSV
df_exploded.to_csv('PORTFOLIO.csv.gz', index=False, compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:270, in CSVFormatter.save(self)
#     260 self.writer = csvlib.writer(
#     261     handles.handle,
#     262     lineterminator=self.lineterminator,
#    (...)
#     267     quotechar=self.quotechar,
#     268 )
# --> 270 self._save()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:275, in CSVFormatter._save(self)
#     274     self._save_header()
# --> 275 self._save_body()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_body(self)
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
# ...

# %%
# Select only the PORTFOLIO and INTITIAL_INVVESTMENT columns
df_selected = df_exploded[['PORTFOLIO', 'INTITIAL_INVVESTMENT']]

# %%
# Write the DataFrame to a CSV file
df_selected.to_csv('PORTFOLIO.csv', index=False, header=False)
